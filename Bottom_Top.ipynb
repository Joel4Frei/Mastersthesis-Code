# %%
# %gui qt
# %matplotlib inline
from pycromanager import Bridge
from PIL import Image
from csbdeep.utils import Path, normalize
from glob import glob
from importlib import reload 
from magicgui import magicgui
from magicgui.widgets import Label, SpinBox, PushButton, Text, Container
from manager.acquisition import acq, acq_stim, acq_multi, acq_multi_dark, acq_mask
from manager.dmd import dmd
from manager.fov import FOV
from manager.preset import preset
from manager.stage import load_pos_file, get_pos_from_mm, stage_position
from matplotlib import pyplot as plt 
from multiprocessing import Process
from napari.layers import Image, Labels
from napari.qt import thread_worker
from pipeline.pipeline_single_frame import add_frame
from pipeline.stimulation import stim_random
from pycromanager import Acquisition, multi_d_acquisition_events

from addons.semantic_segmentation import init_VGG16_pyramid, fd_VGG16_pyramid
from skimage import io
from skimage.color import label2rgb
from skimage.measure import regionprops_table
from skimage.morphology import square
from skimage.segmentation import expand_labels
from sklearn.ensemble import RandomForestClassifier
from stardist import random_label_cmap, _draw_polygons, export_imagej_rois
from stardist.models import StarDist2D
from tqdm import tqdm
from addons.utils import create_folders
from datetime import date
from datetime import datetime
from addons.tools import spot_mask_from_labels
from addons.tools import get_next_experiment_number
from addons.tools import migration_mask
from addons.anch_mask import anch_masking
from cellpose import models
from addons.value import variables_input
from addons.offset import offsetting
from addons import stim
from addons.mail import send_mail_exp, send_mail
from addons.anch_mask import anch_masking
import cv2
import gc
import glob
import importlib.util
import math
import matplotlib
import matplotlib.pyplot as plt
import napari
import nest_asyncio
import numpy as np
import os
import pandas as pd
import pickle as pkl
import queue
import scipy
import skimage
import threading
import time
import trackpy as tp
import os.path
import cv2


#matplotlib.rcParams["image.interpolation"] = None
nest_asyncio.apply()
# Out:
# WARNING:tensorflow:From C:\Users\micro-manager\AppData\Roaming\Python\Python39\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\micro-manager\anaconda3\envs\joelEnv\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.logging.TaskLevelStatusMessage is deprecated. Please use tf.compat.v1.logging.TaskLevelStatusMessage instead.
#
# WARNING:tensorflow:From c:\Users\micro-manager\anaconda3\envs\joelEnv\lib\site-packages\tensorflow_probability\python\internal\backend\numpy\_utils.py:48: The name tf.control_flow_v2_enabled is deprecated. Please use tf.compat.v1.control_flow_v2_enabled instead.
# c:\Users\micro-manager\anaconda3\envs\joelEnv\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\micro-manager\anaconda3\envs\joelEnv\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.11.0 and strictly below 2.14.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.15.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %% [markdown]
# ## Setup connection with micro manager

# %%
bridge = Bridge() #connection to micro-manager
core = bridge.get_core()
studio = bridge.get_studio()
print(bridge.get_core())
dmd = dmd(core) #init dmd device
# Out:
# <pycromanager.core.mmcorej_CMMCore object at 0x000001B5A4AC9CD0>

# %% [markdown]
# violet 395  1 ao25
# blue   440  2 ao24
# cyan   470  3 ao22
# teal   508  7 ao12
# green  555 10 ao26 (not in NIS)
# red    640 14 ao11 (not in NIS)

# %%
nidaq_setup = preset(core) #focus preset
nidaq_setup.settings = [

    ["Spectra RIGHT","Teal_Level",100],
    ["Spectra RIGHT","Teal_Enable",0],
    ["Spectra RIGHT","Cyan_Level",100],
    ["Spectra RIGHT","Cyan_Enable",0],
    ["Spectra RIGHT","Violet_Level",100],
    ["Spectra RIGHT","Violet_Enable",0],
    ["Spectra RIGHT","Green_Level",100],
    ["Spectra RIGHT","Green_Enable",0],
    ["Spectra RIGHT","Blue_Level",100],
    ["Spectra RIGHT","Blue_Enable",0],
    ["Spectra RIGHT","Red_Level",100],
    ["Spectra RIGHT","Red_Enable",0],

    ["Spectra RIGHT","White_Enable",0],
    ['Andor sCMOS LEFT','AuxiliaryOutSource (TTL I/O)','FireAny']
]
nidaq_setup.apply_no_retry()

camera_setup = preset(core) #focus preset
camera_setup.settings = [
    ["Andor sCMOS LEFT","Binning",'2x2'],
    #["Andor sCMOS LEFT","Sensitivity/DynamicRange",'12-bit (low noise)'],
    #["Andor sCMOS LEFT","Exposure",'300'],
    #["Andor sCMOS LEFT","TriggerMode",'Software (Recommended for Live Mode)'],
    ["TILightPath","State",'2'],
    ["Mosaic3","TriggerMode",'InternalExpose'], #InternalSoftware
    #["Andor sCMOS LEFT","PixelReadoutRate",'200 MHz - lowest noise'],
]

camera_setup.apply(core)
# Out:
# Andor sCMOS LEFT: Set Binning to 2x2
# TILightPath: Set State to 2
# Mosaic3: Set TriggerMode to InternalExpose

# %%
black = preset(core)
black.settings = [
    ["Spectra RIGHT","Teal_Enable",0],
    ["Spectra RIGHT","Cyan_Enable",0],
    ["Spectra RIGHT","Violet_Enable",0],
    ["Spectra RIGHT","Green_Enable",0],
    ["Spectra RIGHT","Blue_Enable",0],
    ["Spectra RIGHT","Red_Enable",0],
    ["Wheel-C", "State", 0],
]
black.apply()

# %% [markdown]
# ## Create channel presets
# #### Labels for state devices in micro-manager:
# TIFilterBlock1
# 0: empty
# 1: 86000v2 - Sedat Quad
# 2: 59222 - GFP/mCherry - ET
# 3: 69308 - CFP/YFP/mCherry - ET
# 4: 470lp
# 5: zt 442/514/561
#
# Wheel-C:
# 0: empty
# 1: 84000v2 - DAPI/FITC/TRITC/Cy5 (Em1)
# 2: 59022 - GFP/mCherry - ET (Em)
# 3: CFP 458-482 (Ex)
# 4: YFP 520-550 (Ex)
# 5: CFP 460-500 (Ex)
# 6-9: empty
#
# Spectra Colors:
# Blue (440), Cyan (bright blue 470), Green (yellow), Red, Teal (green/blue 508), Violet (359), White

# %%
mCherry = preset(core)
# 555/25 with same filterwheel as H2B or 575 with 2/2
mCherry.settings = [
    ["Spectra RIGHT","Teal_Enable",0],
    ["Spectra RIGHT","Cyan_Enable",0],
    ["Spectra RIGHT","Violet_Enable",0],
    ["Spectra RIGHT","Blue_Enable",0],
    ["Spectra RIGHT","Red_Enable",0],

    ["TIFilterBlock1", "State", "2"],#2 
    ["Wheel-C", "State", 2],# could also use 1 # standard  2
    ["Spectra RIGHT","Green_Enable",1],
    ["Spectra RIGHT","Green_Level",20] #25
]
mCherry.camera_exposure_time = 400 #150
mCherry.dmd_exposure_time = 100
mCherry.name = "mCherry / ERK-KTR"

mCherry.apply(core)
dmd.all_on()
# Out:
# Spectra RIGHT: Set Teal_Enable to 0
# Spectra RIGHT: Set Cyan_Enable to 0
# Spectra RIGHT: Set Violet_Enable to 0
# Spectra RIGHT: Set Blue_Enable to 0
# Spectra RIGHT: Set Red_Enable to 0
# TIFilterBlock1: Set State to 2
# Wheel-C: Set State to 2
# Spectra RIGHT: Set Green_Enable to 1
# Spectra RIGHT: Set Green_Level to 20

# %%
mruby2 = preset(core)
# 555/25 filter in lumencore
mruby2.settings = [
    ["Spectra RIGHT","Teal_Enable",0],
    ["Spectra RIGHT","Cyan_Enable",0],
    ["Spectra RIGHT","Violet_Enable",0],
    ["Spectra RIGHT","Blue_Enable",0],
    ["Spectra RIGHT","Red_Enable",0],

    ["TIFilterBlock1", "State", "1"],#2 
    ["Wheel-C", "State", 1],# could also use 1 # standard  2
    ["Spectra RIGHT","Green_Enable",1],
    ["Spectra RIGHT","Green_Level",80] #25
]
mruby2.camera_exposure_time = 500 #150
mruby2.dmd_exposure_time = 100
mruby2.name = "mRuby2 / ERK-KTR"

mruby2.apply(core)
dmd.all_on()
# Out:
# Spectra RIGHT: Set Teal_Enable to 0
# Spectra RIGHT: Set Cyan_Enable to 0
# Spectra RIGHT: Set Violet_Enable to 0
# Spectra RIGHT: Set Blue_Enable to 0
# Spectra RIGHT: Set Red_Enable to 0
# TIFilterBlock1: Set State to 1
# Wheel-C: Set State to 1
# Spectra RIGHT: Set Green_Enable to 1
# Spectra RIGHT: Set Green_Level to 80

# %%
miRFP = preset(core)
miRFP.settings = [
    ["TIFilterBlock1", "State", "1"],
    ["Wheel-C", "State", 1],
    ["Spectra RIGHT","Teal_Enable",0],
    ["Spectra RIGHT","Cyan_Enable",0],
    ["Spectra RIGHT","Violet_Enable",0],
    ["Spectra RIGHT","Green_Enable",0],
    ["Spectra RIGHT","Blue_Enable",0],

    ["Spectra RIGHT","Red_Enable",1],
    ["Spectra RIGHT","Red_Level",100]
]
miRFP.camera_exposure_time = 500
miRFP.dmd_exposure_time = 150
miRFP.name = "miRFP"
miRFP.apply()
dmd.all_on()

# %%
OPTO_cal = preset(core) #mCitrine
OPTO_cal.settings = [
    ["Spectra RIGHT","Teal_Enable",0],
    ["Spectra RIGHT","Violet_Enable",0],
    ["Spectra RIGHT","Green_Enable",0],
    ["Spectra RIGHT","Blue_Enable",0],
    ["Spectra RIGHT","Red_Enable",0],

    ["TIFilterBlock1", "State", "1"],#2
    ["Wheel-C", "State", 0],#4 #1
    ["Spectra RIGHT","White_Level",0],
    ["Spectra RIGHT","Cyan_Enable",1], #should be cyan instead of TEAL which worked tho [green, ti=3, cw=1 \\ cyan ti=2,cw=1]
    ["Spectra RIGHT","Cyan_Level",40]
]
OPTO_cal.camera_exposure_time = 400 #100ms for 40x 
OPTO_cal.dmd_exposure_time = 100
OPTO_cal.name = "OPTO_cal"
OPTO_cal.apply(core)
dmd.checker_board()
# Out:
# Spectra RIGHT: Set Teal_Enable to 0
# Spectra RIGHT: Set Violet_Enable to 0
# Spectra RIGHT: Set Green_Enable to 0
# Spectra RIGHT: Set Blue_Enable to 0
# Spectra RIGHT: Set Red_Enable to 0
# TIFilterBlock1: Set State to 1
# Wheel-C: Set State to 0
# Spectra RIGHT: Set White_Level to 0
# Spectra RIGHT: Set Cyan_Enable to 1
# Spectra RIGHT: Set Cyan_Level to 40

# %%
#CHECK EXPRESSION OF OPTOGENETIC CONSTRUCT
OPTO_capture = preset(core) #mCitrine
OPTO_capture.settings = [
    ["Spectra RIGHT","Teal_Enable",1],
    ["Spectra RIGHT","Violet_Enable",0],
    ["Spectra RIGHT","Green_Enable",0],
    ["Spectra RIGHT","Blue_Enable",0],
    ["Spectra RIGHT","Red_Enable",0],
    ["TIFilterBlock1", "State", "5"],#2
    ["Wheel-C", "State", 4],#4 #1 #2
    ["Spectra RIGHT","White_Level",0],
    ["Spectra RIGHT","Cyan_Enable",0], #should be cyan instead of TEAL which worked tho [green, ti=3, cw=1 \\ cyan ti=2,cw=1]
    ["Spectra RIGHT","Teal_Level",100]
]
OPTO_capture.camera_exposure_time = 2000 #100ms for 40x 
OPTO_capture.dmd_exposure_time = 2000
OPTO_capture.name = "514-zt mCitrine"
OPTO_capture.apply(core)
#dmd.checker_board()
dmd.all_on()
# Out:
# Spectra RIGHT: Set Teal_Enable to 1
# Spectra RIGHT: Set Violet_Enable to 0
# Spectra RIGHT: Set Green_Enable to 0
# Spectra RIGHT: Set Blue_Enable to 0
# Spectra RIGHT: Set Red_Enable to 0
# TIFilterBlock1: Set State to 5
# Wheel-C: Set State to 4
# Spectra RIGHT: Set White_Level to 0
# Spectra RIGHT: Set Cyan_Enable to 0
# Spectra RIGHT: Set Teal_Level to 100

# %%
mNeonGreen = preset(core)

#Excitation: 475-510 (Cyan: 470)
#Emission: 510-550

# 555/25 with same filterwheel as H2B or 575 with 2/2
mNeonGreen.settings = [
    ["Spectra RIGHT","Teal_Enable",0],
    ["Spectra RIGHT","Green_Enable",0],
    ["Spectra RIGHT","Violet_Enable",0],
    ["Spectra RIGHT","Blue_Enable",0],
    ["Spectra RIGHT","Red_Enable",0],

    ["TIFilterBlock1", "State", "3"],#2 
    ["Wheel-C", "State", 4],# could also use 1 # standard  2
    ["Spectra RIGHT","Cyan_Enable",1],
    ["Spectra RIGHT","Cyan_Level",25] #25
]
mNeonGreen.camera_exposure_time = 250 #150
mNeonGreen.dmd_exposure_time = 100
mNeonGreen.name = "mNeonGreen"

mNeonGreen.apply(core)
dmd.all_on()
# Out:
# Spectra RIGHT: Set Teal_Enable to 0
# Spectra RIGHT: Set Green_Enable to 0
# Spectra RIGHT: Set Violet_Enable to 0
# Spectra RIGHT: Set Blue_Enable to 0
# Spectra RIGHT: Set Red_Enable to 0
# TIFilterBlock1: Set State to 3
# Wheel-C: Set State to 4
# Spectra RIGHT: Set Cyan_Enable to 1
# Spectra RIGHT: Set Cyan_Level to 25

# %%
black = preset(core)
black.settings = [
    ["Spectra RIGHT","Teal_Enable",0],
    ["Spectra RIGHT","Cyan_Enable",0],
    ["Spectra RIGHT","Violet_Enable",0],
    ["Spectra RIGHT","Green_Enable",0],
    ["Spectra RIGHT","Blue_Enable",0],
    ["Spectra RIGHT","Red_Enable",0],
    ["Wheel-C", "State", 0],
]
black.apply()

# %% [markdown]
# # NAPARI LIVEVIEW

# %%
#channels = [H2B_capture, ERK_capture, OPTO_capture]#OPTO_stim  , OPTO_cal OPTO_capture
channels = [miRFP,mruby2,OPTO_cal,OPTO_capture,mNeonGreen]

#Excitation: 475-510 (Cyan: 470)
#Emission: 510-550

# %% [markdown]
# Creates folder to save images made in Napari.
#
# Change path "parent_folder" to the folder where all the experiments are stored.
#
# Change path "output_path" to the experiment folder, number will be calculated automatically.

# %%
# function to store image
parent_folder = 'Z:\\jfrei\\Data\\experiments\\'
folder_nb = get_next_experiment_number(parent_folder)
output_path = f'Z:\\jfrei\\Data\\experiments\\exp_{folder_nb}\\'
required_folders = ['Images']
create_folders(output_path,required_folders)
# Out:
# Directory Z:\jfrei\Data\experiments\exp_52\Images created

# %%
image_nb = 0
def acquire_single_frame(output_path,image_nb):
    global zmq_lock
    zmq_lock.acquire()
    time.sleep(.5)
    image = acq(core)
    zmq_lock.release()
    time.sleep(.5)

    fname = f'{str(image_nb).zfill(2)}'
    
    io.imsave(output_path+'Images\\'+fname+'.tiff',image, check_contrast=False)
    image_nb += 1
    return image_nb

# %%
# data acquired on microscope or simulated?
simulate = False
clip =[1024, 1024]
# um / px, for correct scaling in napari
size_um = [0.16, 0.16]
#Time between checking again if new image is available
sleep_time = 0.05
# contrast limits for display
clim = [0, 300]
# initialize global variables
# flag to break while loops
acq_running = False
# empty queue for image data\ and z positions
img_queue = queue.Queue()
# xyz data stack
data = np.random.rand(clip[0], clip[1]) * clim[1]
zmq_lock = threading.Lock()
position_list = []

# %%
font = cv2.FONT_HERSHEY_DUPLEX
checker_board = np.kron([[1, 0] * 20, [0, 1] * 20] * 20, np.ones((20, 20))) #https://stackoverflow.com/a/37440123
startup_screen = checker_board*100
cv2.putText(startup_screen,'github.com/hinderling',(40,780), font, 2,(255),2)
#plt.imshow(startup_screen)
data = startup_screen
image_nb = 0


def acquire_data_single_frames():
    global zmq_lock
    zmq_lock.acquire()
    image = acq(core)
    zmq_lock.release()
    
    #print('run grab_image')
    place_data(image)
    
def acquire_data():
    global channels
    global img_queue

    #array = live_manager.snap(False)
    zmq_lock.acquire()
    remaining_image_count = core.get_remaining_image_count()
    zmq_lock.release()
    if remaining_image_count < 1:
        print('No image in uManager queue.')
        time.sleep(0.5)
        return
    
    zmq_lock.acquire()
    array = core.get_last_image()
    #core.clear_circular_buffer()
    zmq_lock.release()
    img_width = int(math.sqrt(len(array)))
    img = np.reshape(array, (img_width,img_width))
    img = img[:,:]
    img_queue.put([channels[1], img])
    return

def acquire_data_single_frames():
    global zmq_lock
    zmq_lock.acquire()
    image = acq(core)
    zmq_lock.release()
    
    #print('run grab_image')
    place_data(image)
    
def acquire_data():
    global channels
    global img_queue

    #array = live_manager.snap(False)
    zmq_lock.acquire()
    remaining_image_count = core.get_remaining_image_count()
    if remaining_image_count < 1:
        zmq_lock.release()
        #print('Warning: No image in uManager queue.')
        time.sleep(0.5)
        return
    try:
        array = core.get_last_image()
    except:
        print('ERROR: No image in uManager queue.')
        time.sleep(0.5)
        return

    zmq_lock.release()
    img_width = int(math.sqrt(len(array)))
    img = np.reshape(array, (img_width,img_width))
    img = img[::,::] #LUCIEN CHANGED IT DROM ::2
    img_queue.put([channels[1], img])
    return

def display_napari(image):
    """ Unpacks z position and reshapes image from pos_img. Writes image into correct
        slice of data, and updates napari display.
        Called by worker thread yielding elements from queue.
        Needs to be in code before worker thread connecting to it.
        Inputs: array pos_img: queue element containing z position and raveled image data.
        Global variables: np.array data: contains image stack
            img_queue: needed only to send task_done() signal.
    """
    global data
    global img_queue
    channel = image[0]
    image= image[1]
    layers[0].data = image
    img_queue.task_done()

@thread_worker
def append_img(img_queue):
    """ Worker thread that adds images to a list.
        Calls either micro-manager data acquisition or functions for simulating data.
        Inputs: img_queue """

    # start microscope data acquisition
    print('Worker started: append_img')
    if not simulate:
         while acq_running:
            acquire_data()
            time.sleep(sleep_time)

    # run with simulated data
    else:
        ii = 0
        while acq_running:
            simulate_data(ii)
            ii = ii + 1
            time.sleep(sleep_time)


@thread_worker(connect={'yielded': display_napari})
def yield_img(img_queue):
    """ Worker thread that checks whether there are elements in the
        queue, reads them out.
        Connected to display_napari function to update display """
    global acq_running
    
    #time_last_frame = time.time()
    #print('yield image')
    
    #print(acq_running)
    while acq_running:
        #time.sleep(sleep_time)
        # get elements from queue while there is more than one element
        # playing it safe: I'm always leaving one element in the queue
        img_queue_size = img_queue.qsize()
        #print(img_queue_size)
        while img_queue.qsize() > 0:
            #print("reading from queue ", img_queue.qsize())
            yield img_queue.get(block = False)
            #time_this_frame = time.time()
            #time_diff = time_this_frame - time_last_frame
            #fps = int(1/time_diff)
        time.sleep(sleep_time)

    # read out last remaining elements after end of acquisition
    while img_queue.qsize() > 0:
        yield img_queue.get(block = False)
@magicgui(call_button = "Start")
def start_acq():
    """ Called when Start button in pressed. Starts workers and resets global variables"""
    global acq_running
    global channels
    global zmq_lock
    if not acq_running:
        #z_range[3] = 0
        acq_running = True
        zmq_lock.acquire()
        core.start_continuous_sequence_acquisition(0)
        zmq_lock.release()
        worker1 = append_img(img_queue)
        worker2 = yield_img(img_queue)
        worker1.start()
        #worker2.start() # doesn't need to be started bc yield is connected
    else:
        print("acquisition already running!")

threshold = 100

@magicgui(slider_float={"widget_type": "FloatSlider", 'max': 1000})
def set_treshold(slider_float=100):
    global threshold
    threshold = slider_float

@magicgui(call_button = "Stop")
def stop_acq():
    # set global acq_running to False to stop other workers
    global acq_running
    global core
    global zmq_lock
    
    zmq_lock.acquire()
    core.stop_sequence_acquisition()    
    zmq_lock.release()
    acq_running = False

    
#a channel is a preset that has EXPOSURE and POWER function
channels_widget = Container()
channels_widgets_list = []
for channel in channels:
    @magicgui(
    call_button = 'SELECT',
    auto_call=False,
    label = {"widget_type": "Label","name":"label","label":channel.name},
    power={"widget_type": "SpinBox","name":"power" ,"label":'%',"min":0,"max": 100},
    exposure={"widget_type": "SpinBox","name":"ms" ,"label":'ms',"min":1,"max": 10000},
    #mode={"choices": ["reflect", "constant", "nearest", "mirror", "wrap"]},
    layout='horizontal',
    channel={'bind': channel} #replace this with channel 
    )
    def channel(label, power: int = channel.settings[-1][2], exposure=channel.camera_exposure_time, channel = channel):
        global channels
        #print(channel.name)
        stop_acq()
        channel.camera_exposure_time = exposure
        channel.set_power(power)
        zmq_lock.acquire()
        channel.apply()
        dmd.all_on()
        zmq_lock.release()
        start_acq()
    channels_widgets_list.append(channel)

channels_widget = Container(widgets=(channels_widgets_list))
        
@magicgui(call_button = "Store position")
def store_pos():
    global channels
    global zmq_lock
    global acq_running
    global position_list
    
    restart = False
    if acq_running:
        stop_acq()
        time.sleep(.5)
        restart = True
    zmq_lock.acquire()
    time.sleep(.5)
    point = core.get_xy_stage_position()
    pfs_offset = core.get_auto_focus_offset()
    x = point.get_x()
    y = point.get_y()
    zmq_lock.release()
    time.sleep(.5)
    position_list.append(stage_position(x,y,pfs_offset))
    if restart:
        start_acq()    

@magicgui(call_button = "Save Image")
def store_img():
    global acq_running
    global core
    global image_nb
    restart = False

    if acq_running:
        stop_acq()
        restart = True
        
    image_nb = acquire_single_frame(output_path,image_nb)

    if restart:
        start_acq()
        
# check if viewer is already open
# if yes: close and reopen
try:
    if viewer:
        viewer.close()
except:
    print("viewer already closed or never opened")
viewer = napari.Viewer(ndisplay=2)


# initialize napari viewer with stack view and random data, reslice view
#scale = [(z_range[1]-z_range[0])/z_range[2]*z_scale, size_um[1], size_um[0]]
layers = [viewer.add_image(data,
                        name = 'zero',
                        colormap = 'gray',
                        interpolation = 'nearest',
                        blending = 'additive',
                        rendering = 'attenuated_mip',
                        #scale = scale,
                        contrast_limits = clim)
         ]

#viewer.dims._roll()
viewer.window.add_dock_widget(start_acq,area='left')
viewer.window.add_dock_widget(stop_acq,area='left')
viewer.window.add_dock_widget(channels_widget,area='left') 
viewer.window.add_dock_widget(store_pos,area='left')
viewer.window.add_dock_widget(store_img, area='left')



viewer.text_overlay.visible = True
#viewer.window.qt_viewer.canvas.measure_fps(callback=update_fps)
# Out:
# viewer already closed or never opened
# 2899610449.py (263): Argument 'interpolation' is deprecated, please use 'interpolation2d' instead. The argument 'interpolation' was deprecated in 0.4.17 and it will be removed in 0.6.0.
# Worker started: append_img
# Worker started: append_img
# Worker started: append_img
# Worker started: append_img
# Worker started: append_img
# Worker started: append_img
# Worker started: append_img
# Worker started: append_img
# Worker started: append_img
# Worker started: append_img
# Worker started: append_img
# Worker started: append_img
# Worker started: append_img
# Worker started: append_img
# Worker started: append_img
# Worker started: append_img
# Worker started: append_img
# Worker started: append_img
# Worker started: append_img
# Worker started: append_img

# %%
len(position_list)
# Out:
# 15

# %% [markdown]
# ## Preview the channel settings

# %%
channels_to_acq = [mruby2,miRFP]# ,OPTO_cal]#, OPTO_cal]#OPTO_stim  , OPTO_cal
frame = acq_multi(channels_to_acq,dmd)
plt.figure(figsize = (10,5),dpi = 300)
fig, axs = plt.subplots(2, len(channels_to_acq), figsize = (10,10),dpi = 300)
fig.suptitle('Acquisition settings preview')
#dark_frame = acq_multi_dark(channels_to_acq,dmd)
#frame = frame + dark_frame*-1
for channel_nb, channel in enumerate(channels_to_acq):
    axs[0][channel_nb].imshow(frame[channel_nb,:,:])
    axs[0][channel_nb] = channel.name
for channel_nb, channel in enumerate(channels_to_acq):
    flat = frame[channel_nb,:,:].flatten()
    axs[1][channel_nb].hist(flat, bins=150, range=(0, 65535/10))
plt.tight_layout()
plt.show()

# %%
#io.imsave('/Users/micro-manager/Desktop/star_pattern_temp_2.tif',frame)

# %%
norm_min = 1
norm_max = 99
stardist_model = StarDist2D.from_pretrained('2D_versatile_fluo')

from csbdeep.utils import Path, normalize
from skimage.morphology import remove_small_objects

## PREPROCESSING ##   
#scale the h2b channel for so StarDist
f_h2b = frame[1,:,:].copy()
f_h2b_scaled = normalize(f_h2b, norm_min,norm_max) #30 95

##Instance segmentation
#https://github.com/stardist/stardist/blob/master/stardist/models/base.py
labels, details = stardist_model.predict_instances(f_h2b_scaled)
# remove small objects:
labels = remove_small_objects(labels, min_size=30, connectivity=1)
plt.figure(dpi=300)
plt.imshow(labels%23)
plt.show()
print(f'found {len(np.unique(labels))} cells')
# Out:
# Found model '2D_versatile_fluo' for 'StarDist2D'.
# WARNING:tensorflow:From C:\Users\micro-manager\AppData\Roaming\Python\Python39\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\micro-manager\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Loading network weights from 'weights_best.h5'.
# Loading thresholds from 'thresholds.json'.
# Using default values: prob_thresh=0.479071, nms_thresh=0.3.
# found 25 cells

# %%
def coordinates_to_lightmap(coordinates, frame_labeled, diameter = 3):
    '''Takes a list of coordinates [(y,x),(y,x),...] and draws an ellipse on a mask for every point. '''

    #Elipse properties
    axesLength = (diameter,diameter) #20, 5 for horizontally stretched ellipse #(10,10) for 40x
    axesLength = (8,8) #20, 5 for horizontally stretched ellipse #(10,10) for 40x
    angle = 0
    startAngle = 0
    endAngle = 360
    color = (1) 
    thickness = -1
    light_mask = np.zeros_like(frame_labeled)

    for xy in coordinates:
        center_coordinates = (int(xy[1]),int(xy[0]))
        light_mask = cv2.ellipse(light_mask, center_coordinates, axesLength, angle, startAngle, endAngle, color, thickness) 
    return light_mask


def spot_mask_from_labels_anchor_top(frame_labeled):
   
    props = skimage.measure.regionprops(frame_labeled)
    props[0].bbox[0]
    rows = [int(prop.bbox[0]) for prop in props] #(min_row, min_col, max_row, max_col)
    cols = [int(prop.centroid[1]) for prop in props] #(row, col).

    #coordinates = [[row-10,col] for row,col in zip(rows,cols)]
    coordinates = [[row-8,col] for row,col in zip(rows,cols)]
    #turn coordinates of centroids to light mask image
    light_mask = coordinates_to_lightmap(coordinates, np.zeros((1024,1024)))

    frame_labeled_expanded = expand_labels(frame_labeled,10)
    light_mask = light_mask.astype('uint8')

    return light_mask.astype('int')

def spot_mask_from_labels_anchor_bottom(frame_labeled):
   
    props = skimage.measure.regionprops(frame_labeled)
    props[0].bbox[0]
    rows = [int(prop.bbox[0]) for prop in props] #(min_row, min_col, max_row, max_col)
    cols = [int(prop.centroid[1]) for prop in props] #(row, col).

    #coordinates = [[row-10,col] for row,col in zip(rows,cols)]
    coordinates = [[row+35,col] for row,col in zip(rows,cols)]
    #turn coordinates of centroids to light mask image
    light_mask = coordinates_to_lightmap(coordinates, np.zeros((1024,1024)))

    frame_labeled_expanded = expand_labels(frame_labeled,10)
    light_mask = light_mask.astype('uint8')

    return light_mask.astype('int')

# %% [markdown]
# ## Migration mask preview

# %%
channels_to_acq = [mruby2,miRFP]# ,OPTO_cal]#, OPTO_cal]#OPTO_stim  , OPTO_cal
frame = acq_multi(channels_to_acq,dmd)

f_h2b = frame[1,:,:].copy()
f_h2b_scaled = normalize(f_h2b, norm_min,norm_max) #30 95

##Instance segmentation
#https://github.com/stardist/stardist/blob/master/stardist/models/base.py
frame_labeled, details = stardist_model.predict_instances(f_h2b_scaled)
frame_labeled = remove_small_objects(frame_labeled, min_size=30, connectivity=1)


light_map_preview_top = spot_mask_from_labels_anchor_top(frame_labeled)

viewer.add_labels(light_map_preview_top)

light_map_preview_bottom = spot_mask_from_labels_anchor_bottom(frame_labeled)

viewer.add_labels(light_map_preview_bottom)
# Out:
# <Labels layer 'light_map_preview_bottom [1]' at 0x1b5a6c7ae20>

# %%
output_path = f'Z:\\jfrei\\Data\\experiments\\exp_{folder_nb}\\'
#output_path = 'c:\\Users\\micro-manager\\Desktop\\temp_joel\\'

required_folders = ['extra']
create_folders(output_path,required_folders)


io.imsave(output_path+'extra\\'+'anchor_mask_top'+'.tiff',light_map_preview_top, check_contrast=False)
io.imsave(output_path+'extra\\'+'anchor_mask_bottom'+'.tiff',light_map_preview_bottom, check_contrast=False)
io.imsave(output_path+'extra\\'+'frame'+'.tiff',f_h2b_scaled, check_contrast=False)
# Out:
# Directory Z:\jfrei\Data\experiments\exp_52\extra created

# %% [markdown]
# ## Calibrate the DMD for the stimulation channel

# %%
OPTO_cal.apply(core)
affine = dmd.calibrate(verbous = True, blur = 6, circle_size = 5, marker_style = 'o')

#np.save(("C:\\Users\\micro-manager\\Documents\\lhinder\\mm_test_files\\affine_20x_2bin_white.npy"), affine)
#np.save(("C:\\Users\\micro-manager\\Documents\\lhinder\\mm_test_files\\affine_20x_2bin_OPTO_STIM.npy"), affine)
# Out:
# Spectra RIGHT: Set Teal_Enable to 0
# Spectra RIGHT: Set Violet_Enable to 0
# Spectra RIGHT: Set Green_Enable to 0
# Spectra RIGHT: Set Blue_Enable to 0
# Spectra RIGHT: Set Red_Enable to 0
# TIFilterBlock1: Set State to 1
# Wheel-C: Set State to 0
# Spectra RIGHT: Set White_Level to 0
# Spectra RIGHT: Set Cyan_Enable to 1
# Spectra RIGHT: Set Cyan_Level to 40

# %%
affine = np.load("C:\\Users\\micro-manager\\Documents\\lhinder\\mm_test_files\\affine_20x_2bin_OPTO_STIM_00.npy")

# %%
np.save(("C:\\Users\\micro-manager\\Documents\\lhinder\\mm_test_files\\affine_40x_induce_apo.npy"), affine)

# %%
affine = np.load("C:\\Users\\micro-manager\\Documents\\lhinder\\mm_test_files\\affine_40x_induce_apo.npy")

# %% [markdown]
# ## Load affine transformation matrix from disk

# %%
affine = np.load("C:\\Users\\micro-manager\\Documents\\lhinder\\mm_test_files\\affine_40x_2bin_OPTO_STIM.npy")
affine = np.load("C:\\Users\\micro-manager\\Documents\\lhinder\\mm_test_files\\affine_20x_2bin_OPTO_STIM.npy")

# %% [markdown]
# ## Load micro-manager POS from live MM session

# %%
#### STORE
import pickle
with open('C:\\Users\\micro-manager\\Documents\\lhinder\\mm_test_files\\pos_list_26.pkl', "wb") as fp:   #Pickling
    pickle.dump(position_list, fp)

# %%
#### LOAD
import pickle

with open('C:\\Users\\micro-manager\\Documents\\lhinder\\mm_test_files\\pos_list_26.pkl', "rb") as fp:   #Pickling
    position_list = pickle.load(fp)

# %% [markdown]
# ## Display the positions and travel paths

# %%
xs = []
ys = []
plt.figure(figsize= (6,6))
for i,pos in enumerate(position_list):
    plt.scatter(pos.x,pos.y,c ='darkblue')
    xs.append(pos.x)
    ys.append(pos.y)
    plt.text(pos.x+100, pos.y, str(i))
print(len(position_list))
plt.plot(xs,ys,c = 'darkblue',alpha = 0.2)
plt.show()
# Out:
# 18

# %%
print(len(position_list))

del position_list[18]

print(len(position_list))
# Out:
# 19
# 18

# %% [markdown]
# ### Defines all values

# %% [markdown]
# Create stim regimes and multiply position list / stim regimes to desires number.
#
# Change standards data: if no value is entered, the standard value will be automatically used.
#
# Change "nb_total_fovs" to adapt the position list and stim regimes to desired number.
#
# Stim diameter properties: 1. Local, 2. Global

# %% [markdown]
# Define all variables needed for experiment.
#
# Change standards data: if no value is entered, the standard value will automatically be used.

# %%
## Enter new standards if desired
standards_data = [
    ["nb_parralel_fovs", 9, "fovs"],
    ["repeats", 20, "times"],
    ["pre_exp_waiting", 0, "minutes"],
    ["nb_time_steps", 40, "steps"],
    ["time_between_frames", 60, "seconds"]
]

standards_columns = ["Input", "Numeric Value", "Unit"]
standards_df = pd.DataFrame(standards_data, columns=standards_columns)

## Create input variables. New inputs can easily be added into list.
input_list = ["nb_parralel_fovs", "repeats", "pre_exp_waiting", "nb_time_steps", "time_between_frames"]
variable_dic = variables_input(input_list, standards_df)
print(variable_dic)
# Out:
# {'nb_parralel_fovs': 9, 'repeats': 20, 'pre_exp_waiting': 0, 'nb_time_steps': 40, 'time_between_frames': 60}
# {'nb_parralel_fovs': 9, 'repeats': 20, 'pre_exp_waiting': 0, 'nb_time_steps': 40, 'time_between_frames': 60}

# %%
## Creates each variable from dictionary
for key, value in variable_dic.items():
    exec(f'{key} = {value}')
    print(key," = ",value)
# Out:
# nb_parralel_fovs  =  9
# repeats  =  20
# pre_exp_waiting  =  0
# nb_time_steps  =  40
# time_between_frames  =  60

# %%
stimulation_frame_list = [1,2]

# %%
stimulation_frame_list = [2,3,4,5]

# %%
stim_regimes = []
stim_reg_0 = {'location': 'top',
                'duration' : 250,
                'intensity': 10,
                'stimulation_frame_list' : [9]}

stim_reg_1 = {'location': 'bottom',
                'duration' : 250,
                'intensity': 10,
                'stimulation_frame_list' : [9]}

stim_reg_2 = {'location': 'top',
                'duration' : 150,
                'intensity': 10,
                'stimulation_frame_list' : [9]}

stim_reg_3 = {'location': 'bottom',
                'duration' : 150,
                'intensity': 10,
                'stimulation_frame_list' : [9]}

stim_regimes = (([stim_reg_0] * 9)*2 + ([stim_reg_1] * 9)*2 + ([stim_reg_2] * 9)*2 + ([stim_reg_3] * 9)*2 )



for n,regs in enumerate(stim_regimes):
    n += 1
    print(regs)
    if n % 9 == 0:
        print('\n')
print(len(stim_regimes))
# Out:
# {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
#
#
# {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
#
#
# {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
#
#
# {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}
#
#
# {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
#
#
# {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
#
#
# {'location': 'bottom', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
#
#
# {'location': 'bottom', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
# {'location': 'bottom', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}
#
#
# 72

# %%
print(repeats * nb_parralel_fovs)
# Out:
# 180

# %%
print(len(position_list))
# Out:
# 18

# %%
nb_total_fovs = 180

stim_regimes, position_list = stim.stim_pos_len_equalizer(stim_regimes, position_list, nb_total_fovs)
# Out:
# Length of the lists:  180 & 180

# %% [markdown]
# ### Check Offset

# %% [markdown]
# ## Initialize the FOVs from a position list

# %% [markdown]
#     '''2. Per-frame. Check Autofocus in the MDA windows, configure Autofocus to
#     use PFSStatus, and make sure to turn off PFS on the microscope stand
#     before starting. If using multiple XY positions, make sure to include
#     the Z drive in the position list (see Kurt's explanation above).
#     Including the PFSOffset in the position list is optional (include only
#     if you want different offsets per position).
#
#
#     when I try to
#     set the Z position with the setPosition function, the PFS is disabled and I
#     have to reactivate it with enableContinuousFocus again.
#
#     I have not worked with the Ti2, but with the Ti, this is baked into the
#     microscope firmware: any movement of the Z-position disables the PFS.  I
#     suspect that the same is true for the Ti2. Since you want the PFS
#     activated in any case, can you simply skip the Z position movement, and
#     rely on the PFS to establish the new position?
#
#
#     On: PFS is locked and actively correcting focus.
#     Off: PFS is deactivated.
#     DIS: PFS out of focus and not working. This could be due to sample out of focus, ilumination problem or impossibility to maintain PFS active.
#     ERR: An error occurred with the PFS, speak with the UIC personnel to help you.
#
#     In the Autofocus properties window, select the microscope PFS with the name "TIPFSStatus" and set its status to "ON".
#     '''

# %%
import pipeline

from importlib import reload
reload(pipeline)
from pipeline import pipeline_single_frame
from pipeline.pipeline_single_frame import add_frame

# %%
### Settings for pipeline REAL MODE ###
test_mode = False
#time_between_frames = 1*60 #in s
#nb_time_steps = int(40)
presets = [miRFP,mruby2]

table_old = None
stim_frame = False
search_range = 15
memory = 3
np.random.seed(6)
lbl_cmap = random_label_cmap()
output_path = f'Z:\\jfrei\\Data\\experiments\\exp_{folder_nb}\\'
#output_path = 'c:\\Users\\micro-manager\\Desktop\\temp_joel\\'


## Create the required folders
required_folders = ['light_mask','raw','mask','stim','tracks','opto_check','mask_ring','spots', 'cellpose_mask']
create_folders(output_path,required_folders)
# Out:
# Directory Z:\jfrei\Data\experiments\exp_52\light_mask created
# Directory Z:\jfrei\Data\experiments\exp_52\raw created
# Directory Z:\jfrei\Data\experiments\exp_52\mask created
# Directory Z:\jfrei\Data\experiments\exp_52\stim created
# Directory Z:\jfrei\Data\experiments\exp_52\tracks created
# Directory Z:\jfrei\Data\experiments\exp_52\opto_check created
# Directory Z:\jfrei\Data\experiments\exp_52\mask_ring created
# Directory Z:\jfrei\Data\experiments\exp_52\spots created
# Directory Z:\jfrei\Data\experiments\exp_52\cellpose_mask created

# %%
def wait_function(fov, time_between_frames,experiment_start_time):
    #check the time since the last exposure
    #wait if its less than the temporal resolution we aim for

    current_time = time.time()-experiment_start_time #relative time since start of experiment

    if fov.last_frame_time != None: #not the first frame 
        #check if we need to wait
        time_scince_last_frame = current_time - fov.last_frame_time
        wait_time = time_between_frames-time_scince_last_frame
        if time_scince_last_frame > time_between_frames:
            # we're to slow.
            seconds_behind = (wait_time)*-1
            if seconds_behind > 5: # Hardware cannot keep up!
                print('Seconds behind: ' + str(round(seconds_behind,2)))
                print('Warning: Use less FOVs, set framerate cannot be achieved.') 
        else:
            # we're to fast. Wait the remaining time.
            print('Wait some time: ' + str(round(wait_time, 2)))
            time.sleep(wait_time)
            
    current_time = time.time()-experiment_start_time #relative time scince start of experiment
    fov.last_frame_time = current_time
    return

# %% [markdown]
# ### Deinfe Lightmask migration mask

# %% [markdown]
# stim_regimes = []
#
# stim_offsets = [(0,0),(2,20),(4,40)] # (y,x) +x --> left, -x --> right, +y --> down, -y --> up
#
# for intensity in [10]:
#
#     for duration in [20,100,500]:
#
#         for stim_offset in stim_offsets:
#
#             for stim_diameter in [4]:
#
#                 stim_regimes.append((intensity,duration,stim_offset,stim_diameter))
#
#                 print(intensity,duration,stim_offset,stim_diameter)
#
# print(len(stim_regimes))

# %% [markdown]
# ### Define function for changing the offset in different direction

# %%
import time
from skimage import io
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import pickle
import time
import trackpy as tp
from PIL import Image
import cv2
import onnx
from onnx_tf.backend import prepare
import tensorflow as tf
import skimage
from skimage.segmentation import expand_labels
from cellpose import models




def dose_response(table,frame_labeled, stim_regime, frame):
    last_frame = table['frame'].max()
    table_f = table[table['frame']==last_frame]
    if len(table_f['particle']) == 0:
        #no cells in this FOV!
        print('Warning: Empty FOV (no cells detected)')
        return [], np.zeros((1024,1024))
    
    props = skimage.measure.regionprops(frame_labeled)
    props[0].bbox[0]
    rows = [int(prop.centroid[0]) for prop in props] #(min_row, min_col, max_row, max_col)
    cols = [int(prop.centroid[1]) for prop in props] #(row, col).

    #coordinates = [[row-10,col] for row,col in zip(rows,cols)]
    coordinates = [[row,col] for row,col in zip(rows,cols)]
    #turn coordinates of centroids to light mask image
    
    location = stim_regime['location']

    if location == 'top':
        light_mask = spot_mask_from_labels_anchor_top(frame_labeled)
    elif location == 'bottom':
        light_mask = spot_mask_from_labels_anchor_bottom(frame_labeled)



    frame_labeled_expanded = expand_labels(frame_labeled,10)
    light_mask_mod = np.logical_and(light_mask ,frame_labeled_expanded == 0)

    return table_f['label'].values, light_mask

# %%
from pipeline.pipeline_single_frame import extract_ring,extract_features

def add_frame(frame, fov, stardist_model, time_point, stim_frame, output_path, norm_min, norm_max, stim_regime):
    time_start = time.time()

    #name under which the images are stored
    fname = f'{str(fov.index).zfill(2)}_{str(time_point).zfill(5)}'

    ## PREPROCESSING ##   
    #scale the h2b channel for so StarDist
    f_h2b = frame[0,:,:].copy()
    f_h2b_scaled = normalize(f_h2b, norm_min,norm_max)

    ##Instance segmentation
    #https://github.com/stardist/stardist/blob/master/stardist/models/base.py
    labels, details = stardist_model.predict_instances(f_h2b_scaled)

    # remove small objects:
    labels = remove_small_objects(labels, min_size=50, connectivity=1) # min_size to filter out nuclei minimum size. Put on 300 for better selection

    #live_seg_q.put(labels)
    
    ## FEATURE EXTRACTION ##                
    table_new,labels_rings = extract_features(labels,frame,details)

    table_new['frame']=time_point
    table_new['stim']=False
    table_new['time']=fov.last_frame_time #relative time scince beginning of experiment
    table_new['led_intensity'] = stim_regime['intensity']
    table_new['stim_duration'] = stim_regime['duration']
    table_new['stim_location'] = stim_regime['location']

    ## COMBINE TABLES ##
    #get the previous tracks frame
    table_old = fov.tracks
    

    print(f'FOV {fov.index} type of old tracks: {type(fov.tracks)}.')
    coordinates = np.array(table_new[['x','y']]) #Convert the df to an array of shape (shape: N, ndim) for trackpy

    if time_point == 0: # or table_old == None
        #this is the first frame
        fov.linker.init_level(coordinates, time_point) #extract positions and convert to horizontal list
        table_new['particle'] = fov.linker.particle_ids
        table_tracked = table_new

    else:
        #this is not the first frame
        if len(table_new.index) != 0:
            fov.linker.next_level(coordinates, time_point) #extract positions and convert to horizontal list
            table_new['particle'] = fov.linker.particle_ids
        table_tracked = pd.concat([table_old,table_new])

    #this is against a in trackpy, where the same ID gets assigned twice in one frame
    table_tracked = table_tracked.drop_duplicates(subset=['particle','frame']) 

    ## TRACK ##
    #tp.quiet(suppress=True) #disable output

    #if len(table.index) != 0: # throws error if table is empty
    #    table_tracked = tp.link_df(table, search_range= search_range, memory=memory)
    #    table_tracked = table_tracked.astype({'particle':'int32'}) #decrease precision
    #else:
    #    table_tracked = table
    

    labels_stim, light_mask = dose_response(table_tracked, labels, stim_regime, frame)        

    light_mask = light_mask.astype(np.uint8)
    fov.light_mask_queue.put(light_mask)  #quickly out the light mask into the queue so we can start the stimulation

    #write in table which labels are stimulated

    if stim_frame:
        table_tracked = table_tracked.reset_index(drop=True)
        stim_index = np.where((table_tracked['frame']==time_point) & (table_tracked['label'].isin(labels_stim)))[0]
        table_tracked.loc[stim_index,'stim']=True


    time_stop = time.time()
    print(f'Time to process one frame: {(time_stop-time_start):0.2f} seconds. Found {len(table_new.index)} cells. Frame {time_point}, FOV {fov.index}.') 

    #only put last 
    
    #put the results into the queue so they can be accessed from parent thread
    fov.tracks_queue.put(table_tracked)


    io.imsave(output_path+'raw\\'+fname+'.tiff',frame, check_contrast=False)
    io.imsave(output_path+'mask\\'+fname+'.tiff',labels, check_contrast=False)
    io.imsave(output_path+'mask_ring\\'+fname+'.tiff',labels_rings, check_contrast=False)


    table_tracked.to_pickle(output_path+'tracks\\'+fname+'.pkl')
    return

# %%
#Change parameters for experiment and enter Experiment description file
#nb_parralel_fovs = 9
#stimulation_frame = 9

name_of_file = "Detail.txt"
description = 'Anchor 20x. Low seeding desnity. Without stiming in the end'
#Don't change
todays_date = date.today()
current_time = datetime.now()
current_time = current_time.strftime("%H:%M:%S")
position_count = len(position_list)
directory = output_path
subject = f'Experiment Nr.{folder_nb} Update'
msg = 'End of experiment.\nExposure of Channels Done!'

# %%
#Define functions for Experiment description file
def file_existance(path, filename):
    import os.path
    file_exists = ""
    check_file = os.path.isfile(path+filename)

    if check_file == True:
        file_exists = True
    else:
        file_exists = False

    return file_exists


def existance_validation(file_exists):
    import sys

    if file_exists == True:
        print("File already exists in directory. Change filename or change directory to prevent data loss.")
        sys.exit()
    else:
        print("Good to go!")


# Check if file exists already
existance = file_existance(directory,name_of_file)
existance_validation(existance)
# Out:
# Good to go!

# %%
#Write data into file
with open(directory+name_of_file, 'w') as details_file:
    #File path and exp Number
    details_file.write(
        f"{todays_date}\n{current_time}\n\nMicroscope: Mönch\n\nExperiment Path: {output_path}\n\n")
    details_file.write(f"FOV count: {position_count}\n\n")

    #Add used channels
    details_file.write(f"Used Channels:\n\t")
    for channel in channels:
        details_file.write(f"{channel}\t\t")
    details_file.write("\n\n")

    #Stimulation time and intesity per frame
    details_file.write(f"Stimulation properties: \n")


    fov_counter = 0
    for x in stim_regimes:
        stim_intensity = x['intensity']
        stim_length = x['duration']
        stim_loc = x['location']
        stimulation_frame = x['stimulation_frame_list']
        details_file.write(
            f"\tFOV {fov_counter}:\tLaser Intensity: {stim_intensity}% \tStimulation Time: {stim_length}ms \tStimulation location: {stim_loc}\n")
        fov_counter += 1

    #Number and duration of frames and which frame is stimulated
    details_file.write(
        f"\nFrame details:\n\tNumber of time steps: {nb_time_steps}.\n\tEach time step is {time_between_frames} seconds.\n\n")
    


    #Add description
    details_file.write(f"Description of experiment:\n\t{description}")

# %%
int(len(position_list)/nb_parralel_fovs)
# Out:
# 20

# %%
print(repeats)
# Out:
# 20

# %%
print(repeats)
print(nb_time_steps)
for stim_reg in stim_regimes:
    print(stim_reg['stimulation_frame_list'])
print(len(stim_regimes))
print(stim_regimes)
# Out:
# 20
# 40
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# [9]
# 180
# [{'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'bottom', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 150, 'intensity': 10, 'stimulation_frame_li ...

# %%
from addons.checklist import check_list

checkpoint_list = ["DMD","CO2","Perfect Focus","Heater","Repeats","Filter"]
check_list(checkpoint_list)
# Out:
# Window is being closed...

# %% [markdown]
# Start Experiment

# %%
for i in range(10):
    time.sleep(60)

fovs = []
for pos_nb, pos in enumerate(position_list):
    treatment = "dose_response"
    fov = FOV(core, pos, treatment, pos_nb,  20, 20,10)
    fovs.append(fov)


### Checks if folder is empty
nbytes = sum(d.stat().st_size for d in os.scandir(output_path+'/raw/') if d.is_file())
ngbytes = nbytes/1000/1000/1000 # B-> KB-> MB-> GB
if ngbytes > 0.01:
    print(':::WARNING:::\nFolder is not empty: '+str(np.round(ngbytes,2))+'GB raw data\n::DISABLE LINE BELOW TO CONTINUE ANYWAYS:::')
    #raise Exception('Folder not empty') #disable this line to allow overwriting

send_mail_exp(0,subject)

for i in range(repeats):
    start_index = i*nb_parralel_fovs
    stop_index = (i+1)*nb_parralel_fovs
    print(stim_regimes[start_index:stop_index])
    fovs_current = fovs[start_index:stop_index]
    stim_regimes_current = stim_regimes[start_index:stop_index]



    ### Start new experiment with 12 FOVs in parralell
    experiment_start_time = time.time()

    for time_step in range(nb_time_steps):
        for fov, stim_regime in zip(fovs_current,stim_regimes_current):    
            fov.move_stage_to_fov()
            stim_frame = False
            
            led_intensity = stim_regime['intensity']
            stim_duration = stim_regime['duration']
            stimulation_frame_list = stim_regime['stimulation_frame_list']

            if time_step in stimulation_frame_list:
                stim_frame = True
        

            wait_function(fov,time_between_frames,experiment_start_time)
            frame = acq_multi(presets,dmd)

            print(frame.shape)
            #start the processing
            if time_step != 0:
                #If not the first frame, get the processed track df from the thread.
                fov.get_tracks_from_thread()
                fov.get_light_mask_from_thread() #wait until stimulation is done            

                print(f'FOV {fov.index} track file has {len(fov.tracks.index)} entries.')
                #wait until the old thread terminates
                fov.pipeline_thread.join()

            #start new thread                  

            fov.pipeline_thread = threading.Thread(target = add_frame, args = [frame, fov, stardist_model, time_step, stim_frame, output_path, norm_min, norm_max, stim_regime])
            fov.pipeline_thread.start()

            if stim_frame:
                OPTO_cal.set_power(led_intensity) #Set LED power
                OPTO_cal.camera_exposure_time = stim_duration #Set exposure time

                #wait until the computation is done,plot()
                #then directly project the image

                stim_img = acq_stim(fov.light_mask,OPTO_cal,affine,dmd)        
                fname = f'{str(fov.index).zfill(2)}_{str(time_step).zfill(5)}'
                io.imsave(output_path+'stim\\'+fname+'.tiff',stim_img, check_contrast=False)
                io.imsave(output_path+'light_mask\\'+fname+'.tiff',fov.light_mask, check_contrast=False)

            else:
                # save an empty image so the dimensions match up in napari
                fname = f'{str(fov.index).zfill(2)}_{str(time_step).zfill(5)}'
                io.imsave(output_path+'stim\\'+fname+'.tiff',np.zeros((1024,1024)).astype(np.uint8), check_contrast=False)
                io.imsave(output_path+'light_mask\\'+fname+'.tiff',np.zeros((1024,1024)).astype(np.uint8), check_contrast=False)

            #time_stop = time.time()
            #processing_time = time_stop - time_start
            
            
            #if  time_step == nb_time_steps-1:     
                #last frame, take exposure of opto sensor
            #    opto_check_preset = [miRFP,mruby2, OPTO_capture]
            #    frame = acq_multi(opto_check_preset,dmd)
            #    io.imsave(output_path+'opto_check\\'+fname+'.tiff',frame, check_contrast=False)

            gc.collect()
    time.sleep(10*60) ##wait until starting a new batch of FOVs
    send_mail_exp(i+1,subject)

    if  i == repeats-1:
        #last repeat, take exposure of opto sensor
        opto_check_preset = [miRFP,mruby2, OPTO_capture]
        frame = acq_multi(opto_check_preset,dmd)
        io.imsave(output_path+'opto_check\\'+fname+'.tiff',frame, check_contrast=False)
        send_mail(msg,subject)
# Out:
# Email sent!
# [{'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}, {'location': 'top', 'duration': 250, 'intensity': 10, 'stimulation_frame_list': [9]}]
# (2, 1024, 1024)
# FOV 0 type of old tracks: <class 'NoneType'>.
# Time to process one frame: 1.25 seconds. Found 15 cells. Frame 0, FOV 0.
# (2, 1024, 1024)
# FOV 1 type of old tracks: <class 'NoneType'>.
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 0, FOV 1.
# (2, 1024, 1024)
# FOV 2 type of old tracks: <class 'NoneType'>.
# Time to process one frame: 1.20 seconds. Found 12 cells. Frame 0, FOV 2.
# (2, 1024, 1024)
# FOV 3 type of old tracks: <class 'NoneType'>.
# Time to process one frame: 1.18 seconds. Found 9 cells. Frame 0, FOV 3.
# (2, 1024, 1024)
# FOV 4 type of old tracks: <class 'NoneType'>.
# Time to process one frame: 1.19 seconds. Found 11 cells. Frame 0, FOV 4.
# (2, 1024, 1024)
# FOV 5 type of old tracks: <class 'NoneType'>.
# Time to process one frame: 1.16 seconds. Found 5 cells. Frame 0, FOV 5.
# (2, 1024, 1024)
# FOV 6 type of old tracks: <class 'NoneType'>.
# Time to process one frame: 1.22 seconds. Found 14 cells. Frame 0, FOV 6.
# (2, 1024, 1024)
# FOV 7 type of old tracks: <class 'NoneType'>.
# Time to process one frame: 1.20 seconds. Found 11 cells. Frame 0, FOV 7.
# (2, 1024, 1024)
# Wait some time: 33.41
# FOV 8 type of old tracks: <class 'NoneType'>.
# Time to process one frame: 1.22 seconds. Found 16 cells. Frame 0, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 15 entries.
# Wait some time: 0.11
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 15 cells. Frame 1, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 10 entries.
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 11 cells. Frame 1, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 12 entries.
# Wait some time: 0.11
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 13 cells. Frame 1, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 9 entries.
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.18 seconds. Found 8 cells. Frame 1, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 11 entries.
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 11 cells. Frame 1, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 5 entries.
# Wait some time: 0.07
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.15 seconds. Found 5 cells. Frame 1, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 14 entries.
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 15 cells. Frame 1, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 11 entries.
# Wait some time: 0.18
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 11 cells. Frame 1, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 16 entries.
# Wait some time: 33.45
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.24 seconds. Found 17 cells. Frame 1, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 30 entries.
# Wait some time: 0.15
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 14 cells. Frame 2, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 21 entries.
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 2, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 25 entries.
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 10 cells. Frame 2, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 17 entries.
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.17 seconds. Found 8 cells. Frame 2, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 22 entries.
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 11 cells. Frame 2, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 10 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.15 seconds. Found 5 cells. Frame 2, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 29 entries.
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 15 cells. Frame 2, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 22 entries.
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.24 seconds. Found 13 cells. Frame 2, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 33 entries.
# Wait some time: 33.42
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 15 cells. Frame 2, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 44 entries.
# Wait some time: 0.07
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 14 cells. Frame 3, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 31 entries.
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 0.25
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 3, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 35 entries.
# Wait some time: 0.01
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 3, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 25 entries.
# Wait some time: 0.01
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.18 seconds. Found 8 cells. Frame 3, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 33 entries.
# Wait some time: 0.03
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 11 cells. Frame 3, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 15 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.15 seconds. Found 6 cells. Frame 3, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 44 entries.
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 14 cells. Frame 3, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 35 entries.
# Wait some time: 0.02
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 13 cells. Frame 3, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 48 entries.
# Wait some time: 33.41
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.23 seconds. Found 14 cells. Frame 3, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 58 entries.
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 0.04
# Time to process one frame: 1.18 seconds. Found 14 cells. Frame 4, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 41 entries.
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 0.19
# Time to process one frame: 1.21 seconds. Found 10 cells. Frame 4, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 45 entries.
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.18 seconds. Found 10 cells. Frame 4, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 33 entries.
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 4, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 44 entries.
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 11 cells. Frame 4, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 21 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.17 seconds. Found 7 cells. Frame 4, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 58 entries.
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 12 cells. Frame 4, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 48 entries.
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 11 cells. Frame 4, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 62 entries.
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 33.14
# Time to process one frame: 1.20 seconds. Found 15 cells. Frame 4, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 72 entries.
# Wait some time: 0.04
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 14 cells. Frame 5, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 51 entries.
# Wait some time: 0.32
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 10 cells. Frame 5, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 55 entries.
# Wait some time: 0.21
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 5, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 43 entries.
# Wait some time: 0.01
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.16 seconds. Found 8 cells. Frame 5, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 55 entries.
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 11 cells. Frame 5, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 28 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.16 seconds. Found 7 cells. Frame 5, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 70 entries.
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 14 cells. Frame 5, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 59 entries.
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 14 cells. Frame 5, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 77 entries.
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 32.95
# Time to process one frame: 1.21 seconds. Found 17 cells. Frame 5, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 86 entries.
# Wait some time: 0.09
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 14 cells. Frame 6, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 61 entries.
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 0.21
# Time to process one frame: 1.19 seconds. Found 10 cells. Frame 6, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 65 entries.
# Wait some time: 0.06
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 6, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 51 entries.
# Wait some time: 0.01
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.17 seconds. Found 8 cells. Frame 6, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 66 entries.
# Wait some time: 0.11
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 11 cells. Frame 6, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 35 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 8 cells. Frame 6, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 84 entries.
# Wait some time: 0.03
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 15 cells. Frame 6, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 73 entries.
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 11 cells. Frame 6, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 94 entries.
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 32.9
# Time to process one frame: 1.21 seconds. Found 15 cells. Frame 6, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 100 entries.
# Wait some time: 0.1
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 14 cells. Frame 7, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 71 entries.
# Wait some time: 0.23
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 7, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 75 entries.
# Wait some time: 0.2
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 7, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 59 entries.
# Wait some time: 0.0
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.17 seconds. Found 8 cells. Frame 7, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 77 entries.
# Wait some time: 0.14
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 11 cells. Frame 7, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 43 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 0.03
# Time to process one frame: 1.16 seconds. Found 9 cells. Frame 7, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 99 entries.
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 15 cells. Frame 7, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 84 entries.
# Wait some time: 0.17
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 13 cells. Frame 7, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 109 entries.
# Wait some time: 32.93
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 15 cells. Frame 7, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 114 entries.
# Wait some time: 0.07
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 14 cells. Frame 8, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 81 entries.
# Wait some time: 0.31
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 10 cells. Frame 8, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 85 entries.
# Wait some time: 0.05
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 8, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 67 entries.
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.18 seconds. Found 9 cells. Frame 8, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 88 entries.
# Wait some time: 0.12
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 11 cells. Frame 8, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 52 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 0.02
# Time to process one frame: 1.17 seconds. Found 9 cells. Frame 8, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 114 entries.
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 16 cells. Frame 8, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 97 entries.
# Wait some time: 0.34
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 13 cells. Frame 8, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 124 entries.
# Wait some time: 33.01
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 20 cells. Frame 8, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 128 entries.
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 0.89 seconds. Found 14 cells. Frame 9, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 91 entries.
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 0.88 seconds. Found 10 cells. Frame 9, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 95 entries.
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 0.88 seconds. Found 10 cells. Frame 9, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 76 entries.
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 0.86 seconds. Found 8 cells. Frame 9, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 99 entries.
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 0.89 seconds. Found 11 cells. Frame 9, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 61 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 0.88 seconds. Found 11 cells. Frame 9, FOV 5.
# Seconds behind: 6.07
# Warning: Use less FOVs, set framerate cannot be achieved.
# (2, 1024, 1024)
# FOV 6 track file has 130 entries.
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 0.91 seconds. Found 16 cells. Frame 9, FOV 6.
# Seconds behind: 7.05
# Warning: Use less FOVs, set framerate cannot be achieved.
# (2, 1024, 1024)
# FOV 7 track file has 110 entries.
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 0.89 seconds. Found 13 cells. Frame 9, FOV 7.
# Seconds behind: 8.02
# Warning: Use less FOVs, set framerate cannot be achieved.
# (2, 1024, 1024)
# FOV 8 track file has 144 entries.
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 0.90 seconds. Found 15 cells. Frame 9, FOV 8.
# Wait some time: 23.94
# (2, 1024, 1024)
# FOV 0 track file has 142 entries.
# Wait some time: 0.97
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 14 cells. Frame 10, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 101 entries.
# Wait some time: 1.11
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.18 seconds. Found 10 cells. Frame 10, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 105 entries.
# Wait some time: 1.14
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 10 cells. Frame 10, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 84 entries.
# Wait some time: 1.13
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.18 seconds. Found 9 cells. Frame 10, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 110 entries.
# Wait some time: 0.96
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 11 cells. Frame 10, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 72 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.19
# Time to process one frame: 1.18 seconds. Found 11 cells. Frame 10, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 146 entries.
# Wait some time: 1.05
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 15 cells. Frame 10, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 123 entries.
# Wait some time: 1.12
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 14 cells. Frame 10, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 159 entries.
# Wait some time: 25.09
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 16 cells. Frame 10, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 156 entries.
# Wait some time: 1.04
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 14 cells. Frame 11, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 111 entries.
# Wait some time: 1.17
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 11, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 115 entries.
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.05
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 11, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 93 entries.
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.0
# Time to process one frame: 1.19 seconds. Found 9 cells. Frame 11, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 121 entries.
# Wait some time: 1.01
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.17 seconds. Found 10 cells. Frame 11, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 83 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.2
# Time to process one frame: 1.18 seconds. Found 10 cells. Frame 11, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 161 entries.
# Wait some time: 1.03
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.23 seconds. Found 17 cells. Frame 11, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 137 entries.
# Wait some time: 1.12
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 12 cells. Frame 11, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 175 entries.
# Wait some time: 24.97
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 17 cells. Frame 11, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 170 entries.
# Wait some time: 1.06
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.24 seconds. Found 14 cells. Frame 12, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 121 entries.
# Wait some time: 1.14
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.23 seconds. Found 10 cells. Frame 12, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 125 entries.
# Wait some time: 1.13
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.23 seconds. Found 10 cells. Frame 12, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 102 entries.
# Wait some time: 1.16
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 8 cells. Frame 12, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 131 entries.
# Wait some time: 0.98
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 12 cells. Frame 12, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 93 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.2
# Time to process one frame: 1.19 seconds. Found 10 cells. Frame 12, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 178 entries.
# Wait some time: 1.04
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 16 cells. Frame 12, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 149 entries.
# Wait some time: 1.05
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 11 cells. Frame 12, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 192 entries.
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 24.93
# Time to process one frame: 1.20 seconds. Found 13 cells. Frame 12, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 184 entries.
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.0
# Time to process one frame: 1.19 seconds. Found 14 cells. Frame 13, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 131 entries.
# Wait some time: 1.16
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 13, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 135 entries.
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.07
# Time to process one frame: 1.22 seconds. Found 10 cells. Frame 13, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 110 entries.
# Wait some time: 1.12
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.17 seconds. Found 8 cells. Frame 13, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 143 entries.
# Wait some time: 0.92
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 14 cells. Frame 13, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 103 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.14
# Time to process one frame: 1.19 seconds. Found 11 cells. Frame 13, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 194 entries.
# Wait some time: 1.05
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 15 cells. Frame 13, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 160 entries.
# Wait some time: 1.04
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 13, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 205 entries.
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 24.92
# Time to process one frame: 1.21 seconds. Found 13 cells. Frame 13, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 198 entries.
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 0.93
# Time to process one frame: 1.21 seconds. Found 14 cells. Frame 14, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 141 entries.
# Wait some time: 1.12
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 14, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 145 entries.
# Wait some time: 1.18
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 10 cells. Frame 14, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 118 entries.
# Wait some time: 1.1
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.18 seconds. Found 10 cells. Frame 14, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 157 entries.
# Wait some time: 0.99
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.18 seconds. Found 11 cells. Frame 14, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 114 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.07
# Time to process one frame: 1.18 seconds. Found 11 cells. Frame 14, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 209 entries.
# Wait some time: 1.02
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 16 cells. Frame 14, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 170 entries.
# Wait some time: 1.04
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 14 cells. Frame 14, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 218 entries.
# Wait some time: 24.96
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 12 cells. Frame 14, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 212 entries.
# Wait some time: 0.98
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 14 cells. Frame 15, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 151 entries.
# Wait some time: 1.14
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 10 cells. Frame 15, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 155 entries.
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.07
# Time to process one frame: 1.19 seconds. Found 11 cells. Frame 15, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 128 entries.
# Wait some time: 1.1
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.18 seconds. Found 9 cells. Frame 15, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 168 entries.
# Wait some time: 0.98
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 11 cells. Frame 15, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 125 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.23
# Time to process one frame: 1.18 seconds. Found 12 cells. Frame 15, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 225 entries.
# Wait some time: 1.07
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 15 cells. Frame 15, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 184 entries.
# Wait some time: 1.13
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 13 cells. Frame 15, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 230 entries.
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 24.9
# Time to process one frame: 1.20 seconds. Found 14 cells. Frame 15, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 226 entries.
# Wait some time: 1.06
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 14 cells. Frame 16, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 161 entries.
# Wait some time: 1.1
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 10 cells. Frame 16, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 166 entries.
# Wait some time: 1.17
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.17 seconds. Found 10 cells. Frame 16, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 137 entries.
# Wait some time: 1.09
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.18 seconds. Found 9 cells. Frame 16, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 179 entries.
# Wait some time: 0.98
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 10 cells. Frame 16, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 137 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.19
# Time to process one frame: 1.18 seconds. Found 12 cells. Frame 16, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 240 entries.
# Wait some time: 1.1
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.23 seconds. Found 16 cells. Frame 16, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 197 entries.
# Wait some time: 1.11
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 11 cells. Frame 16, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 244 entries.
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 24.9
# Time to process one frame: 1.21 seconds. Found 15 cells. Frame 16, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 240 entries.
# Wait some time: 1.07
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 14 cells. Frame 17, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 171 entries.
# Wait some time: 1.15
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.18 seconds. Found 10 cells. Frame 17, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 176 entries.
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.08
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 17, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 146 entries.
# Wait some time: 1.11
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.17 seconds. Found 9 cells. Frame 17, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 189 entries.
# Wait some time: 0.96
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 11 cells. Frame 17, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 149 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.19
# Time to process one frame: 1.20 seconds. Found 11 cells. Frame 17, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 256 entries.
# Wait some time: 0.99
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 15 cells. Frame 17, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 208 entries.
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 0.98
# Time to process one frame: 1.21 seconds. Found 10 cells. Frame 17, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 259 entries.
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 24.93
# Time to process one frame: 1.19 seconds. Found 13 cells. Frame 17, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 254 entries.
# Wait some time: 1.07
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 14 cells. Frame 18, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 181 entries.
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.01
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 18, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 186 entries.
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.05
# Time to process one frame: 1.19 seconds. Found 10 cells. Frame 18, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 155 entries.
# Wait some time: 1.13
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.17 seconds. Found 11 cells. Frame 18, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 200 entries.
# Wait some time: 1.03
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 18, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 160 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.19
# Time to process one frame: 1.18 seconds. Found 12 cells. Frame 18, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 271 entries.
# Wait some time: 1.08
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 15 cells. Frame 18, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 218 entries.
# Wait some time: 1.11
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 12 cells. Frame 18, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 272 entries.
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 24.92
# Time to process one frame: 1.20 seconds. Found 12 cells. Frame 18, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 268 entries.
# Wait some time: 1.08
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 15 cells. Frame 19, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 191 entries.
# Wait some time: 1.14
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.18 seconds. Found 10 cells. Frame 19, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 196 entries.
# Wait some time: 1.17
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.18 seconds. Found 10 cells. Frame 19, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 166 entries.
# Wait some time: 1.11
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.18 seconds. Found 9 cells. Frame 19, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 210 entries.
# Wait some time: 1.01
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 11 cells. Frame 19, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 172 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.13
# Time to process one frame: 1.18 seconds. Found 12 cells. Frame 19, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 286 entries.
# Wait some time: 1.09
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 15 cells. Frame 19, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 230 entries.
# Wait some time: 1.12
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 15 cells. Frame 19, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 284 entries.
# Wait some time: 24.99
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 13 cells. Frame 19, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 283 entries.
# Wait some time: 1.05
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 14 cells. Frame 20, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 201 entries.
# Wait some time: 1.11
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 10 cells. Frame 20, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 206 entries.
# Wait some time: 1.17
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.18 seconds. Found 10 cells. Frame 20, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 175 entries.
# Wait some time: 1.2
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.17 seconds. Found 9 cells. Frame 20, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 221 entries.
# Wait some time: 0.98
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 11 cells. Frame 20, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 184 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.17
# Time to process one frame: 1.19 seconds. Found 13 cells. Frame 20, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 301 entries.
# Wait some time: 1.02
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 16 cells. Frame 20, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 245 entries.
# Wait some time: 1.09
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 11 cells. Frame 20, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 297 entries.
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 24.92
# Time to process one frame: 1.20 seconds. Found 13 cells. Frame 20, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 297 entries.
# Wait some time: 1.08
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 14 cells. Frame 21, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 211 entries.
# Wait some time: 1.17
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 21, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 216 entries.
# Wait some time: 1.17
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.18 seconds. Found 9 cells. Frame 21, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 184 entries.
# Wait some time: 1.15
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.18 seconds. Found 9 cells. Frame 21, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 232 entries.
# Wait some time: 0.93
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.58 seconds. Found 13 cells. Frame 21, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 197 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.16
# Time to process one frame: 1.20 seconds. Found 13 cells. Frame 21, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 317 entries.
# Wait some time: 1.11
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 15 cells. Frame 21, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 256 entries.
# Wait some time: 1.11
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.23 seconds. Found 11 cells. Frame 21, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 310 entries.
# Wait some time: 25.03
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 14 cells. Frame 21, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 311 entries.
# Wait some time: 1.03
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.23 seconds. Found 14 cells. Frame 22, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 221 entries.
# Wait some time: 1.13
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 22, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 225 entries.
# Wait some time: 1.18
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.18 seconds. Found 9 cells. Frame 22, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 193 entries.
# Wait some time: 1.16
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.18 seconds. Found 9 cells. Frame 22, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 245 entries.
# Wait some time: 0.96
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 13 cells. Frame 22, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 210 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.18
# Time to process one frame: 1.18 seconds. Found 11 cells. Frame 22, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 332 entries.
# Wait some time: 1.14
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 16 cells. Frame 22, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 267 entries.
# Wait some time: 1.19
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 12 cells. Frame 22, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 324 entries.
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.Wait some time: 24.95
#
# Time to process one frame: 1.21 seconds. Found 14 cells. Frame 22, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 325 entries.
# Wait some time: 1.05
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 14 cells. Frame 23, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 231 entries.
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.07
# Time to process one frame: 1.19 seconds. Found 10 cells. Frame 23, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 234 entries.
# Wait some time: 1.14
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 9 cells. Frame 23, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 202 entries.
# Wait some time: 1.1
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.18 seconds. Found 10 cells. Frame 23, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 258 entries.
# Wait some time: 0.98
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 12 cells. Frame 23, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 221 entries.
# Wait some time: 1.43
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.17 seconds. Found 11 cells. Frame 23, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 348 entries.
# Wait some time: 1.02
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.23 seconds. Found 16 cells. Frame 23, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 279 entries.
# Wait some time: 1.16
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.23 seconds. Found 12 cells. Frame 23, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 338 entries.
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 24.94
# Time to process one frame: 1.20 seconds. Found 13 cells. Frame 23, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 339 entries.
# Wait some time: 1.07
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 14 cells. Frame 24, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 241 entries.
# Wait some time: 1.13
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 10 cells. Frame 24, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 243 entries.
# Wait some time: 1.18
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 9 cells. Frame 24, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 212 entries.
# Wait some time: 1.11
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.18 seconds. Found 9 cells. Frame 24, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 270 entries.
# Wait some time: 0.99
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 12 cells. Frame 24, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 232 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.2
# Time to process one frame: 1.19 seconds. Found 11 cells. Frame 24, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 364 entries.
# Wait some time: 1.13
# FOV 6 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.24 seconds. Found 15 cells. Frame 24, FOV 6.
# (2, 1024, 1024)
# FOV 7 track file has 291 entries.
# Wait some time: 1.19
# FOV 7 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 10 cells. Frame 24, FOV 7.
# (2, 1024, 1024)
# FOV 8 track file has 351 entries.
# Wait some time: 24.99
# FOV 8 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 12 cells. Frame 24, FOV 8.
# (2, 1024, 1024)
# FOV 0 track file has 353 entries.
# Wait some time: 1.04
# FOV 0 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 14 cells. Frame 25, FOV 0.
# (2, 1024, 1024)
# FOV 1 track file has 251 entries.
# FOV 1 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.04
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 25, FOV 1.
# (2, 1024, 1024)
# FOV 2 track file has 252 entries.
# FOV 2 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.08
# Time to process one frame: 1.18 seconds. Found 9 cells. Frame 25, FOV 2.
# (2, 1024, 1024)
# FOV 3 track file has 221 entries.
# Wait some time: 1.11
# FOV 3 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.17 seconds. Found 9 cells. Frame 25, FOV 3.
# (2, 1024, 1024)
# FOV 4 track file has 282 entries.
# Wait some time: 0.98
# FOV 4 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 11 cells. Frame 25, FOV 4.
# (2, 1024, 1024)
# FOV 5 track file has 243 entries.
# FOV 5 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.11
# Time to process one frame: 1.19 seconds. Found 11 cells. Frame 25, FOV 5.
# (2, 1024, 1024)
# FOV 6 track file has 379 entries.
# ...
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 29, FOV 12.
# (2, 1024, 1024)
# FOV 13 track file has 384 entries.
# Wait some time: 1.05
# FOV 13 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 15 cells. Frame 29, FOV 13.
# (2, 1024, 1024)
# FOV 14 track file has 794 entries.
# Wait some time: 1.32
# FOV 14 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.28 seconds. Found 28 cells. Frame 29, FOV 14.
# (2, 1024, 1024)
# FOV 15 track file has 678 entries.
# Wait some time: 1.01
# FOV 15 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.26 seconds. Found 24 cells. Frame 29, FOV 15.
# (2, 1024, 1024)
# FOV 16 track file has 474 entries.
# Wait some time: 1.15
# FOV 16 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.24 seconds. Found 16 cells. Frame 29, FOV 16.
# (2, 1024, 1024)
# FOV 17 track file has 460 entries.
# Wait some time: 25.06
# FOV 17 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 18 cells. Frame 29, FOV 17.
# (2, 1024, 1024)
# FOV 9 track file has 345 entries.
# Wait some time: 1.18
# FOV 9 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 11 cells. Frame 30, FOV 9.
# (2, 1024, 1024)
# FOV 10 track file has 548 entries.
# Wait some time: 1.3
# FOV 10 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.23 seconds. Found 18 cells. Frame 30, FOV 10.
# (2, 1024, 1024)
# FOV 11 track file has 472 entries.
# Wait some time: 1.01
# FOV 11 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.23 seconds. Found 15 cells. Frame 30, FOV 11.
# (2, 1024, 1024)
# FOV 12 track file has 316 entries.
# FOV 12 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 1.08
# Time to process one frame: 1.22 seconds. Found 10 cells. Frame 30, FOV 12.
# (2, 1024, 1024)
# FOV 13 track file has 399 entries.
# Wait some time: 1.15
# FOV 13 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 14 cells. Frame 30, FOV 13.
# (2, 1024, 1024)
# FOV 14 track file has 822 entries.
# Wait some time: 1.09
# FOV 14 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.27 seconds. Found 28 cells. Frame 30, FOV 14.
# (2, 1024, 1024)
# FOV 15 track file has 702 entries.
# Wait some time: 1.08
# FOV 15 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.27 seconds. Found 24 cells. Frame 30, FOV 15.
# (2, 1024, 1024)
# FOV 16 track file has 490 entries.
# Wait some time: 1.1
# FOV 16 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 16 cells. Frame 30, FOV 16.
# (2, 1024, 1024)
# FOV 17 track file has 478 entries.
# Wait some time: 24.98
# FOV 17 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 16 cells. Frame 30, FOV 17.
# (2, 1024, 1024)
# FOV 9 track file has 356 entries.
# Wait some time: 1.13
# FOV 9 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.23 seconds. Found 11 cells. Frame 31, FOV 9.
# (2, 1024, 1024)
# FOV 10 track file has 566 entries.
# Wait some time: 1.12
# FOV 10 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.25 seconds. Found 18 cells. Frame 31, FOV 10.
# (2, 1024, 1024)
# FOV 11 track file has 487 entries.
# Wait some time: 1.09
# FOV 11 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 15 cells. Frame 31, FOV 11.
# (2, 1024, 1024)
# FOV 12 track file has 326 entries.
# Wait some time: 1.16
# FOV 12 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 10 cells. Frame 31, FOV 12.
# (2, 1024, 1024)
# FOV 13 track file has 413 entries.
# Wait some time: 1.14
# FOV 13 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 14 cells. Frame 31, FOV 13.
# (2, 1024, 1024)
# FOV 14 track file has 850 entries.
# Wait some time: 1.15
# FOV 14 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.29 seconds. Found 26 cells. Frame 31, FOV 14.
# (2, 1024, 1024)
# FOV 15 track file has 726 entries.
# Wait some time: 1.04
# FOV 15 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.27 seconds. Found 25 cells. Frame 31, FOV 15.
# (2, 1024, 1024)
# FOV 16 track file has 506 entries.
# Wait some time: 1.18
# FOV 16 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.23 seconds. Found 15 cells. Frame 31, FOV 16.
# (2, 1024, 1024)
# FOV 17 track file has 494 entries.
# Wait some time: 25.01
# FOV 17 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 16 cells. Frame 31, FOV 17.
# (2, 1024, 1024)
# FOV 9 track file has 367 entries.
# Wait some time: 1.08
# FOV 9 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 11 cells. Frame 32, FOV 9.
# (2, 1024, 1024)
# FOV 10 track file has 584 entries.
# Wait some time: 1.18
# FOV 10 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 17 cells. Frame 32, FOV 10.
# (2, 1024, 1024)
# FOV 11 track file has 502 entries.
# FOV 11 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 0.94
# Time to process one frame: 1.23 seconds. Found 15 cells. Frame 32, FOV 11.
# (2, 1024, 1024)
# FOV 12 track file has 336 entries.
# Wait some time: 1.16
# FOV 12 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 10 cells. Frame 32, FOV 12.
# (2, 1024, 1024)
# FOV 13 track file has 427 entries.
# Wait some time: 1.08
# FOV 13 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 13 cells. Frame 32, FOV 13.
# (2, 1024, 1024)
# FOV 14 track file has 876 entries.
# Wait some time: 1.1
# FOV 14 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.29 seconds. Found 30 cells. Frame 32, FOV 14.
# (2, 1024, 1024)
# FOV 15 track file has 751 entries.
# Wait some time: 1.08
# FOV 15 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.27 seconds. Found 25 cells. Frame 32, FOV 15.
# (2, 1024, 1024)
# FOV 16 track file has 521 entries.
# Wait some time: 1.19
# FOV 16 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 15 cells. Frame 32, FOV 16.
# (2, 1024, 1024)
# FOV 17 track file has 510 entries.
# Wait some time: 25.0
# FOV 17 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 16 cells. Frame 32, FOV 17.
# (2, 1024, 1024)
# FOV 9 track file has 378 entries.
# Wait some time: 1.25
# FOV 9 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 11 cells. Frame 33, FOV 9.
# (2, 1024, 1024)
# FOV 10 track file has 601 entries.
# Wait some time: 1.03
# FOV 10 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 17 cells. Frame 33, FOV 10.
# (2, 1024, 1024)
# FOV 11 track file has 517 entries.
# Wait some time: 1.14
# FOV 11 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 16 cells. Frame 33, FOV 11.
# (2, 1024, 1024)
# FOV 12 track file has 346 entries.
# Wait some time: 1.13
# FOV 12 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.19 seconds. Found 10 cells. Frame 33, FOV 12.
# (2, 1024, 1024)
# FOV 13 track file has 440 entries.
# Wait some time: 1.08
# FOV 13 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 16 cells. Frame 33, FOV 13.
# (2, 1024, 1024)
# FOV 14 track file has 906 entries.
# Wait some time: 1.09
# FOV 14 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.27 seconds. Found 28 cells. Frame 33, FOV 14.
# (2, 1024, 1024)
# FOV 15 track file has 776 entries.
# Wait some time: 1.11
# FOV 15 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.29 seconds. Found 25 cells. Frame 33, FOV 15.
# (2, 1024, 1024)
# FOV 16 track file has 536 entries.
# Wait some time: 1.22
# FOV 16 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 16 cells. Frame 33, FOV 16.
# (2, 1024, 1024)
# FOV 17 track file has 526 entries.
# Wait some time: 24.97
# FOV 17 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 16 cells. Frame 33, FOV 17.
# (2, 1024, 1024)
# FOV 9 track file has 389 entries.
# Wait some time: 1.2
# FOV 9 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 12 cells. Frame 34, FOV 9.
# (2, 1024, 1024)
# FOV 10 track file has 618 entries.
# Wait some time: 1.12
# FOV 10 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 17 cells. Frame 34, FOV 10.
# (2, 1024, 1024)
# FOV 11 track file has 533 entries.
# Wait some time: 1.03
# FOV 11 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.23 seconds. Found 17 cells. Frame 34, FOV 11.
# (2, 1024, 1024)
# FOV 12 track file has 356 entries.
# Wait some time: 1.29
# FOV 12 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 10 cells. Frame 34, FOV 12.
# (2, 1024, 1024)
# FOV 13 track file has 456 entries.
# Wait some time: 1.12
# FOV 13 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 14 cells. Frame 34, FOV 13.
# (2, 1024, 1024)
# FOV 14 track file has 934 entries.
# Wait some time: 1.27
# FOV 14 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.28 seconds. Found 31 cells. Frame 34, FOV 14.
# (2, 1024, 1024)
# FOV 15 track file has 801 entries.
# Wait some time: 1.08
# FOV 15 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.27 seconds. Found 23 cells. Frame 34, FOV 15.
# (2, 1024, 1024)
# FOV 16 track file has 552 entries.
# Wait some time: 1.18
# FOV 16 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 18 cells. Frame 34, FOV 16.
# (2, 1024, 1024)
# FOV 17 track file has 542 entries.
# Wait some time: 25.21
# FOV 17 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.23 seconds. Found 16 cells. Frame 34, FOV 17.
# (2, 1024, 1024)
# FOV 9 track file has 401 entries.
# Wait some time: 1.02
# FOV 9 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 13 cells. Frame 35, FOV 9.
# (2, 1024, 1024)
# FOV 10 track file has 635 entries.
# Wait some time: 1.3
# FOV 10 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 15 cells. Frame 35, FOV 10.
# (2, 1024, 1024)
# FOV 11 track file has 550 entries.
# Wait some time: 0.94
# FOV 11 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.23 seconds. Found 16 cells. Frame 35, FOV 11.
# (2, 1024, 1024)
# FOV 12 track file has 366 entries.
# FOV 12 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 0.86
# Time to process one frame: 1.22 seconds. Found 10 cells. Frame 35, FOV 12.
# (2, 1024, 1024)
# FOV 13 track file has 470 entries.
# Wait some time: 1.19
# FOV 13 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.20 seconds. Found 12 cells. Frame 35, FOV 13.
# (2, 1024, 1024)
# FOV 14 track file has 964 entries.
# Wait some time: 1.09
# FOV 14 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.25 seconds. Found 25 cells. Frame 35, FOV 14.
# (2, 1024, 1024)
# FOV 15 track file has 824 entries.
# Wait some time: 1.08
# FOV 15 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.21 seconds. Found 12 cells. Frame 35, FOV 15.
# (2, 1024, 1024)
# FOV 16 track file has 570 entries.
# Wait some time: 1.25
# FOV 16 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.24 seconds. Found 13 cells. Frame 35, FOV 16.
# (2, 1024, 1024)
# FOV 17 track file has 558 entries.
# Wait some time: 25.17
# FOV 17 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.24 seconds. Found 14 cells. Frame 35, FOV 17.
# (2, 1024, 1024)
# FOV 9 track file has 414 entries.
# Exception in thread Thread-698:
# Traceback (most recent call last):
#   File "c:\Users\micro-manager\anaconda3\envs\joelEnv\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "c:\Users\micro-manager\anaconda3\envs\joelEnv\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\micro-manager\AppData\Local\Temp\ipykernel_9488\2081530913.py", line 67, in add_frame
#   File "C:\Users\micro-manager\AppData\Local\Temp\ipykernel_9488\1638505349.py", line 30, in dose_response
# IndexError: list index out of range
# FOV 9 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Wait some time: 0.74
# (2, 1024, 1024)
# FOV 10 track file has 650 entries.
# Exception in thread Thread-699:
# Traceback (most recent call last):
#   File "c:\Users\micro-manager\anaconda3\envs\joelEnv\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "c:\Users\micro-manager\anaconda3\envs\joelEnv\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\micro-manager\AppData\Local\Temp\ipykernel_9488\2081530913.py", line 67, in add_frame
#   File "C:\Users\micro-manager\AppData\Local\Temp\ipykernel_9488\1638505349.py", line 30, in dose_response
# IndexError: list index out of range
# FOV 10 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# (2, 1024, 1024)
# FOV 11 track file has 566 entries.
# Exception in thread Thread-700:
# Traceback (most recent call last):
#   File "c:\Users\micro-manager\anaconda3\envs\joelEnv\lib\threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "c:\Users\micro-manager\anaconda3\envs\joelEnv\lib\threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\micro-manager\AppData\Local\Temp\ipykernel_9488\2081530913.py", line 67, in add_frame
#   File "C:\Users\micro-manager\AppData\Local\Temp\ipykernel_9488\1638505349.py", line 30, in dose_response
# IndexError: list index out of range
# FOV 11 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# (2, 1024, 1024)
# FOV 12 track file has 376 entries.
# Wait some time: 0.49
# FOV 12 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.86 seconds. Found 338 cells. Frame 36, FOV 12.
# (2, 1024, 1024)
# FOV 13 track file has 482 entries.
# Wait some time: 1.36
# FOV 13 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 2.00 seconds. Found 454 cells. Frame 36, FOV 13.
# (2, 1024, 1024)
# FOV 14 track file has 989 entries.
# Wait some time: 1.12
# FOV 14 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.90 seconds. Found 357 cells. Frame 36, FOV 14.
# (2, 1024, 1024)
# FOV 15 track file has 836 entries.
# Wait some time: 1.1
# FOV 15 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 11 cells. Frame 36, FOV 15.
# (2, 1024, 1024)
# FOV 16 track file has 583 entries.
# Wait some time: 1.17
# FOV 16 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.22 seconds. Found 11 cells. Frame 36, FOV 16.
# (2, 1024, 1024)
# FOV 17 track file has 572 entries.
# Wait some time: 25.04
# FOV 17 type of old tracks: <class 'pandas.core.frame.DataFrame'>.
# Time to process one frame: 1.23 seconds. Found 13 cells. Frame 36, FOV 17.
# (2, 1024, 1024)
